# %% [markdown]
# <a href="https://colab.research.google.com/github/410650641/introduction-to-computers/blob/main/0608.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
list1=[1,2,3,4]

# %%
list1
# Out:
# [1, 2, 3, 4]

# %%
list2=["蘋果","香蕉",'橘子']

# %%
list2
# Out:
# ['蘋果', '香蕉', '橘子']

# %%
list3=[1,'香蕉',True]

# %%
list3
# Out:
# [1, '香蕉', True]

# %%
list4=[]

# %%
list4
# Out:
# []

# %%
list1=[1,2,3,4]

# %%
print(list1)
# Out:
# [1, 2, 3, 4]

# %%
print(list1[0])
# Out:
# 1

# %%
print(list1[1])
# Out:
# 2

# %%
print(list1[2])
# Out:
# 3

# %%
print(list1[3])
# Out:
# 4

# %%
print(list1[4])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-21-827113708aff> in <module>()
# ----> 1 print(list1[4])
#
# IndexError: list index out of range

# %%
list4=["蘋果","香蕉",'橘子']

# %%
print(list4[0])
print(list4[1])
print(list4[2])
# Out:
# 蘋果
# 香蕉
# 橘子

# %%
print(list4[3])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-25-9576ac69e6be> in <module>()
# ----> 1 print(list4[3])
#
# IndexError: list index out of range

# %%
print(list4[-1])
# Out:
# 橘子

# %%
print(list4[-2])
print(list4[-3])
# Out:
# 香蕉
# 蘋果

# %%
print(list4[-4])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-29-0c21896b40b4> in <module>()
# ----> 1 print(list4[-4])
#
# IndexError: list index out of range

# %%
list5=[['tom','1234']],['mary','abcd'],['david','5678']

# %%
print(list5[1])
print(list5[0])
# Out:
# ['mary', 'abcd']
# [['tom', '1234']]

# %%
print(list5[1][1])
# Out:
# abcd

# %%
print(list5[0][0])
# Out:
# ['tom', '1234']

# %%
print(list5[1][0])
# Out:
# mary

# %%
list6=[85,79,93]

# %%
print('國文成績：',list6[0],'分')
print('數學成績：',list6[1],'分')
print('英文成績：',list6[2],'分')
# Out:
# 國文成績： 85 分
# 數學成績： 79 分
# 英文成績： 93 分

# %%
scores=[85,79,93]

# %%
print('國文成績：%d分'%scores[0])
print('數學成績：%d分'%scores[1])
print('英文成績：%d分'%scores[2])
# Out:
# 國文成績：85分
# 數學成績：79分
# 英文成績：93分

# %%
list7=[1,2,3,4]

# %%
print(list7[0])
# Out:
# 1

# %%
list7[0]=9

# %%
print(list7[0])
# Out:
# 9

# %%
print(list7)
# Out:
# [9, 2, 3, 4]

# %%
list8=["蘋果","香蕉",'橘子']

# %%
print(list8)
# Out:
# ['蘋果', '香蕉', '橘子']

# %%
for s in list8:
  print(s,end=",")
# Out:
# 蘋果,香蕉,橘子,

# %%
list9=['123','apple','True']

# %%
for s in list9:
  print(s,end='\n')
# Out:
# 123
# apple
# True

# %%
list9=['123','apple','True']
print(len(list9))
# Out:
# 3

# %%
list9=['123','apple','True']
for i in range(len(list9)):
  print(list9[i])
# Out:
# 123
# apple
# True

# %% [markdown]
# ![截圖 2022-06-08 上午9.18.16.png](data:image/png;base64,...)

# %%
scores=[85,79,93]
s=['國文','英文','數學']
for i in range(len(s)):
  print("%s的成績為:%s分"%(s[i],scores[i]))
# Out:
# 國文的成績為:85分
# 英文的成績為:79分
# 數學的成績為:93分

# %% [markdown]
# ![截圖 2022-06-08 上午9.18.20.png](data:image/png;base64,...)

# %%
list9=[1,2,3]
name=['Tom','Mary','Tony']
for i in range(len(name)):
  print("編號：%d 姓名：%s"%(list9[i],name[i]))
# Out:
# 編號：1 姓名：Tom
# 編號：2 姓名：Mary
# 編號：3 姓名：Tony
